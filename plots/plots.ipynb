# %%
#theme

EMERALD_PALETTE = [
    "#064E3B",  # dark emerald
    "#047857",  # emerald
    "#059669",  # vivid emerald
    "#10B981",  # soft green
    "#34D399",  # light green
    "#6EE7B7",  # mint
    "#A7F3D0"   # pale mint
]
